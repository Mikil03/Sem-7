# %% [markdown]
# ## Kidney Stone prediction using MRI
# ### Dataset Link - https://www.kaggle.com/datasets/mohammedrizwanmalik/kidney-stones-mri-and-ct-scans

# %%
import cv2
import matplotlib.pyplot as plt
from skimage.filters import sobel

# %% [markdown]
# ### Filters for image

# %%
stone = cv2.imread('kidney_stone.png')
stone = cv2.resize(stone, (500,500))
# cv2.imshow('Stone', stone)
# cv2.waitKey()
plt.imshow(stone,cmap='gray')
plt.axis('off')
plt.title('Kidney Stone present')
plt.show()

# %%
laplace_img = cv2.Laplacian(stone,-5)
# cv2.imshow('Laplace', laplace_img)
# cv2.waitKey()
plt.imshow(laplace_img,cmap='gray')
plt.axis('off')
plt.title('Laplacian Filter')
plt.show()

# %%
sobel_img = sobel(stone)
# cv2.imshow('Sobel', sobel_img)
# cv2.waitKey()
plt.imshow(sobel_img,cmap='gray')
plt.axis('off')
plt.title('SSobel Filter')
plt.show()

# %% [markdown]
# ### Normalizing

# %%
print(stone.max(), stone.min())
stone = stone/stone.max()
print(stone.max(), stone.min())
# Out:
# 255 0
# 1.0 0.0

# %%
plt.imshow(stone,cmap='gray')
plt.axis('off')
plt.title('After Normalizing')
plt.show()

# %% [markdown]
# ### ROI

# %%
crop = stone[0:300,50:450]
plt.imshow(crop,cmap='gray')
plt.axis('off')
plt.title('ROI')
plt.show()
